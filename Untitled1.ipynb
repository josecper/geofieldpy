# %%
import mehler
import importlib; importlib.reload(mehler)
# Out:
# <module 'mehler' from '/home/josecper/Programs/python/mehler.py'>

# %%
import numpy
import scipy

from matplotlib import pyplot
# %matplotlib nbagg

# %%
theta = numpy.linspace(0, numpy.deg2rad(20), 100)

# %%
y=[numpy.real(mehler.mehler(1, p, numpy.pi, theta)) for p in (1,5,10,15,20)]

# %%
fig, ax = pyplot.subplots()

for yy in y:
    ax.plot(theta, yy)
    
ax.set_yscale('log')
# Out:
# <img src="data:image/png;base64,...">
