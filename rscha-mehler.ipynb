# %%
import mehler
import importlib; importlib.reload(mehler)
# Out:
# <module 'mehler' from '/home/josecper/Programs/python/mehler.py'>

# %%
import numpy
import scipy

from matplotlib import pyplot
# %matplotlib nbagg

# %%
theta_0 = numpy.deg2rad(20)
theta = numpy.linspace(0, theta_0, 100)

# %%
y=[numpy.real(mehler.mehler(1, p, numpy.pi, theta)) for p in (1,5,10,15,20)]

# %%
fig, ax = pyplot.subplots()

for yy in y:
    ax.plot(theta, yy)
    
ax.set_yscale('log')
ax.set_ybound(1e-10, 1e2)
# Out:
# <img src="data:image/png;base64,...">

# %%
y=[numpy.real(mehler.mehler(m, 1, numpy.pi, theta)) for m in (0, 1, 2, 3, 4, 5)]

# %%
fig, ax = pyplot.subplots()

for yy in y:
    ax.plot(theta, yy)
    
ax.set_yscale('log')
ax.set_ybound(1e-11, 1e2)
# Out:
# <img src="data:image/png;base64,...">

# %%
y=[numpy.real(mehler.hypergeom(m, 1, numpy.pi, theta)) for m in (0, 1, 2, 3, 4, 5)]

# %%
fig, ax = pyplot.subplots()

ax.plot(theta, y[0])
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### esto está guay bien ok

# %%
import scha
import fibonacci_sphere
import trig

thetav, phiv = fibonacci_sphere.grid(n=40000)
inside_cap = trig.angulardist(thetav, phiv, 0, 0) < theta_0
thetav = thetav[inside_cap]; phiv = phiv[inside_cap]

z = numpy.real(mehler.mehler(2, 1, numpy.pi, thetav))*numpy.cos(2*phiv)

# %%
fig, ax = pyplot.subplots()

c=scha.polar_tricontour(z, thetav, phiv, theta_0, ax, cmap='viridis', scale='minmax')
ax.axis('off')
ax.set_title("$K_{p=1}^{m=2} cos(2\phi)$")
pyplot.colorbar(c, ax=ax, aspect=40, drawedges=False)
# Out:
# <img src="data:image/png;base64,...">

# %%
z
# Out:
# array([ 0.01994964,  0.03988505,  0.0078846 , ...,  0.03220934,
#         0.00053337,  0.05249371])

# %%
import mfunnorm
importlib.reload(mfunnorm)
# Out:
# <module 'mfunnorm' from '/home/josecper/Programs/python/mfunnorm.cpython-35m-x86_64-linux-gnu.so'>

# %%
mfunnorm.mfunnorm(2, 1, thetav[0], theta_0, 0)
# Out:
# tuple

# %%
magical=numpy.frompyfunc(lambda x:mfunnorm.mfunnorm(1,1, x, theta_0, 1)[0], 1, 1)

# %%
fnorm=mfunnorm.fnorm(1, 1, theta_0)[0]

# %%
zz=numpy.float64(magical(thetav))*numpy.cos(phiv)

# %% [markdown]
# #### calculado con thebault

# %%
fig, ax = pyplot.subplots()

c=scha.polar_tricontour(zz, thetav, phiv, theta_0, ax, cmap='viridis', scale='minmax')
ax.axis('off')
ax.set_title("$K_{p=1}^{m=1} cos(\phi)$")
pyplot.colorbar(c, ax=ax, aspect=40, drawedges=False)
# Out:
# <img src="data:image/png;base64,...">

# %%
def mehler_thebault(m, fn, theta, theta_0, norm=0):
    uf = numpy.frompyfunc(lambda x: mfunnorm.mfunnorm(m,fn, x, theta_0, norm)[0], 1, 1)
    return numpy.float64(uf(theta))

# %%
theta = numpy.linspace(0.0001, theta_0, 100)

# %%
y=[mehler.mehler_t(m, 0, theta, theta_0, 1) for m in (0, 1, 2, 3, 4, 5)]

# %%
fig, ax = pyplot.subplots()

for yy in y:
    ax.plot(theta, yy)
    
ax.set_yscale('log')
ax.vlines(theta_0, *ax.get_ybound(), linestyles='--')
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
y=[mehler.mehler_t(1, tau, theta, theta_0, 1) for tau in (0, 1, 5, 10, 15, 20)]

# %%
fig, ax = pyplot.subplots()

for yy in y:
    ax.plot(theta, yy)
    
ax.set_yscale('log')
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
import mehler

# %%
y=[mehler.mehler_t(m, 0, theta, theta_0, 1) for m in (0, 1, 2)]

# %%
fig, ax = pyplot.subplots()

for yy in y:
    ax.plot(theta, yy)
    
#ax.set_yscale('log')
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
y=[mehler.dmehler_t(m, 0, theta, theta_0, 1) for m in (0, 1, 2)]

# %%
fig, ax = pyplot.subplots()

for yy in y:
    ax.plot(theta, yy)
    
ax.set_yscale('log')
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %% [markdown]
# la derivada no es como muy tocha?

# %%
y=[mehler.dmehler_t_numeric(m, 0, theta, theta_0, normalized=True) for m in (0, 1, 2)]

# %%
fig, ax = pyplot.subplots()

for yy in y:
    ax.plot(theta, yy)
    
ax.set_yscale('log')
# Out:
# <img src="data:image/png;base64,...">
